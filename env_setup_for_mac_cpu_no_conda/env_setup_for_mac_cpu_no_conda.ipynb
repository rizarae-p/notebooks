# %% [markdown]
# # `DEEPLABCUT.yaml` is not applicable to macOS with no cuda: cannot run DLC GUI

# %% [markdown]
# Errors encountered with the library version dependencies:

# %% [markdown]
# ### Issue 1: `pythonw` not part of *requirements.txt* and *DEEPLABCUT.yaml*

# %%
(DEEPLABCUT) raeさんは ~に >> pythonw -m ~/Desktop/DLCdev/deeplabcut
zsh: command not found: pythonw

# %% [markdown]
# ### Issue 2: `tensorflow` is not found even if it is available in the environment

# %%
(DEEPLABCUT) raeさんは DLCdevに >> pythonw -m deeplabcut          と言います!★ 
Traceback (most recent call last):
  File "/usr/local/anaconda3/lib/python3.10/runpy.py", line 187, in _run_module_as_main
    mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
  File "/usr/local/anaconda3/lib/python3.10/runpy.py", line 146, in _get_module_details
    return _get_module_details(pkg_main_name, error)
  File "/usr/local/anaconda3/lib/python3.10/runpy.py", line 110, in _get_module_details
    __import__(pkg_name)
  File "/Users/rae/Desktop/DLCdev/deeplabcut/__init__.py", line 16, in <module>
    import tensorflow as tf

# %% [markdown]
# ### Issue 3: Incompatible `pyQt` library

# %%
(DEEPLABCUT) raeさんは DLCdevに >> pythonw -m deeplabcut          と言います!★ 
2023-06-27 11:50:52.954444: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
Loading DLC 2.3.1...
Starting GUI...
qt.core.plugin.loader: In /usr/local/anaconda3/envs/DEEPLABCUT/plugins/platforms/libqcocoa.dylib:
  Plugin uses incompatible Qt library (5.15.0) [release]
qt.core.plugin.loader: In /usr/local/anaconda3/envs/DEEPLABCUT/plugins/platforms/libqminimal.dylib:
  Plugin uses incompatible Qt library (5.15.0) [release]
qt.core.plugin.loader: In /usr/local/anaconda3/envs/DEEPLABCUT/plugins/platforms/libqoffscreen.dylib:
  Plugin uses incompatible Qt library (5.15.0) [release]
qt.core.plugin.loader: In /usr/local/anaconda3/envs/DEEPLABCUT/plugins/platforms/libqwebgl.dylib:
  Plugin uses incompatible Qt library (5.15.0) [release]
qt.qpa.plugin: Could not find the Qt platform plugin "cocoa" in ""
This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.

*** Received signal 6 ***
*** BEGIN MANGLED STACK TRACE ***
0   libtensorflow_framework.2.dylib     0x000000010a31ed57 _ZN10tensorflow7testingL17StacktraceHandlerEiP9__siginfoPv + 183
1   libsystem_platform.dylib            0x00007ff80aae75ed _sigtramp + 29
2   ???                                 0x687420646e696620 0x0 + 7526676492964161056
3   libsystem_c.dylib                   0x00007ff80a9e0b45 abort + 123
4   QtCore                              0x000000012a0742f9 _Z6qAbortv + 9
5   QtCore                              0x000000012a0780a9 _ZNK14QMessageLogger5debugEPKcz + 585
6   QtCore                              0x000000012a3e0e77 _ZNK14QMessageLogger5fatalEPKcz + 213
7   QtGui                               0x000000012a68faf9 _ZN22QGuiApplicationPrivate25createPlatformIntegrationEv + 11081
8   QtGui                               0x000000012a68d68c _ZN22QGuiApplicationPrivate25createPlatformIntegrationEv + 1756
9   QtGui                               0x000000012a68fd6b _ZN22QGuiApplicationPrivate21createEventDispatcherEv + 27
10  QtCore                              0x000000012a0d852a _ZN23QCoreApplicationPrivate4initEv + 1898
11  QtGui                               0x000000012a6898b9 _ZN22QGuiApplicationPrivate4initEv + 57
12  QtWidgets                           0x000000016198ea82 _ZN19QApplicationPrivate4initEv + 34
13  QtWidgets.abi3.so                   0x0000000162367150 _ZL23QApplicationConstructorP7_objectS0_PP19QApplicationWrapper + 96
14  QtWidgets.abi3.so                   0x0000000162363f57 _ZL21Sbk_QApplication_InitP7_objectS0_S0_ + 263
15  python3.8                           0x0000000106ae0f18 type_call + 296
16  python3.8                           0x0000000106b733e8 _PyEval_EvalFrameDefault + 60136
17  python3.8                           0x0000000106a555f5 _PyFunction_Vectorcall + 421
18  python3.8                           0x0000000106b6e213 _PyEval_EvalFrameDefault + 39187
19  python3.8                           0x0000000106b62b18 _PyEval_EvalCodeWithName + 712
20  python3.8                           0x0000000106b5daa2 builtin_exec + 322
21  python3.8                           0x0000000106ab1d97 cfunction_vectorcall_FASTCALL + 103
22  python3.8                           0x0000000106b6e213 _PyEval_EvalFrameDefault + 39187
23  python3.8                           0x0000000106a55994 _PyFunction_Vectorcall + 1348
24  python3.8                           0x0000000106b6e213 _PyEval_EvalFrameDefault + 39187
25  python3.8                           0x0000000106a55994 _PyFunction_Vectorcall + 1348
26  python3.8                           0x0000000106a54be7 PyVectorcall_Call + 455
27  python3.8                           0x0000000106c0451e pymain_run_module + 206
28  python3.8                           0x0000000106c03ffe pymain_run_python + 238
29  python3.8                           0x0000000106c03ec5 Py_RunMain + 37
30  python3.8                           0x0000000106a243b8 main + 56
31  dyld                                0x00007ff80a76041f start + 1903
*** END MANGLED STACK TRACE ***

*** Begin stack trace ***
	tensorflow::CurrentStackTrace()
	tensorflow::testing::StacktraceHandler(int, __siginfo*, void*)
	_sigtramp
	
	abort
	qAbort()
	QMessageLogger::debug(char const*, ...) const
	QMessageLogger::fatal(char const*, ...) const
	QGuiApplicationPrivate::createPlatformIntegration()
	QGuiApplicationPrivate::createPlatformIntegration()
	QGuiApplicationPrivate::createEventDispatcher()
	QCoreApplicationPrivate::init()
	QGuiApplicationPrivate::init()
	QApplicationPrivate::init()
	QApplicationConstructor(_object*, _object*, QApplicationWrapper**)
	Sbk_QApplication_Init(_object*, _object*, _object*)
	type_call
	_PyEval_EvalFrameDefault
	_PyFunction_Vectorcall
	_PyEval_EvalFrameDefault
	_PyEval_EvalCodeWithName
	builtin_exec
	cfunction_vectorcall_FASTCALL
	_PyEval_EvalFrameDefault
	_PyFunction_Vectorcall
	_PyEval_EvalFrameDefault
	_PyFunction_Vectorcall
	PyVectorcall_Call
	pymain_run_module
	pymain_run_python
	Py_RunMain
	main
	start
*** End stack trace ***

# %% [markdown]
# ### Issue 4: `matplotlib` version issue

# %%
python -m deeplabcut                                                                                                                                       と言います!★ 
2023-06-27 11:55:51.455897: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
Loading DLC 2.3.1...
Traceback (most recent call last):
  File "/usr/local/anaconda3/envs/DEEPLABCUT/lib/python3.8/runpy.py", line 185, in _run_module_as_main
    mod_name, mod_spec, code = _get_module_details(mod_name, _Error)
  File "/usr/local/anaconda3/envs/DEEPLABCUT/lib/python3.8/runpy.py", line 144, in _get_module_details
    return _get_module_details(pkg_main_name, error)
  File "/usr/local/anaconda3/envs/DEEPLABCUT/lib/python3.8/runpy.py", line 111, in _get_module_details
    __import__(pkg_name)
  File "/Users/rae/Desktop/DLCdev/deeplabcut/__init__.py", line 27, in <module>
    from deeplabcut.gui.tabs.label_frames import (
  File "/Users/rae/Desktop/DLCdev/deeplabcut/gui/tabs/__init__.py", line 11, in <module>
    from deeplabcut.gui.tabs.analyze_videos import AnalyzeVideos
  File "/Users/rae/Desktop/DLCdev/deeplabcut/gui/tabs/analyze_videos.py", line 16, in <module>
    from deeplabcut.gui.widgets import ConfigEditor
  File "/Users/rae/Desktop/DLCdev/deeplabcut/gui/widgets.py", line 21, in <module>
    from matplotlib.backends.backend_qt5agg import (
  File "/usr/local/anaconda3/envs/DEEPLABCUT/lib/python3.8/site-packages/matplotlib/backends/backend_qt5agg.py", line 7, in <module>
    from .backend_qtagg import (    # noqa: F401, E402 # pylint: disable=W0611
  File "/usr/local/anaconda3/envs/DEEPLABCUT/lib/python3.8/site-packages/matplotlib/backends/backend_qtagg.py", line 12, in <module>
    from .backend_qt import (
  File "/usr/local/anaconda3/envs/DEEPLABCUT/lib/python3.8/site-packages/matplotlib/backends/backend_qt.py", line 73, in <module>
    _MODIFIER_KEYS = [
  File "/usr/local/anaconda3/envs/DEEPLABCUT/lib/python3.8/site-packages/matplotlib/backends/backend_qt.py", line 74, in <listcomp>
    (_to_int(getattr(_enum("QtCore.Qt.KeyboardModifier"), mod)),
TypeError: int() argument must be a string, a bytes-like object or a number, not 'KeyboardModifier'

# %% [markdown]
# ### Issue 5: `pySide` issue

# %%
(DEEPLABCUT) raeさんは DLCdevに >> python -m deeplabcut                                                                                                                                       と言います!★ 
2023-06-27 12:42:41.694964: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
Loading DLC 2.3.1...
Starting GUI...
Traceback (most recent call last):
  File "/Users/rae/Desktop/DLCdev/deeplabcut/gui/window.py", line 386, in _create_project
    dlg = ProjectCreator(self)
  File "/Users/rae/Desktop/DLCdev/deeplabcut/gui/tabs/create_project.py", line 35, in __init__
    self.user_frame = self.lay_out_user_frame()
  File "/Users/rae/Desktop/DLCdev/deeplabcut/gui/tabs/create_project.py", line 46, in lay_out_user_frame
    user_frame.setFrameShape(user_frame.StyledPanel)
AttributeError: 'PySide6.QtWidgets.QFrame' object has no attribute 'StyledPanel'

# %% [markdown]
# ## Diagnosis: `pySide` compat issues with macOS
# Ref: https://github.com/Homebrew/homebrew-core/issues/126374

# %%
(dlc) raeさんは DLCdevに >> brew install pyside@2 python@3.11 cmake                                                                                                                           と言います!★ 
==> Downloading https://formulae.brew.sh/api/formula.jws.json
##################################################################################################################################################################################################### 100.0%
==> Downloading https://formulae.brew.sh/api/cask.jws.json
##################################################################################################################################################################################################### 100.0%
Warning: Treating cmake as a formula. For the cask, use homebrew/cask/cmake
==> Fetching dependencies for pyside@2: lz4, zstd, llvm@15, openssl@3, python@3.10, libpng, freetype, pcre2, gettext, glib, jpeg-turbo, giflib, libtiff, webp and qt@5
==> Fetching lz4
==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.9.4
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/lz4/blobs/sha256:6a911ee2a3ea072f414d2983d532b28c34b63a68ff388a0008e1528dc0668838
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:6a911ee2a3ea072f414d2983d532b28c34b63a68ff388a0008e1528dc0668838?se=2023-06-27T12%3A00%3A00Z&sig=P01mMIAwprWY0OLXLIR0Dg
##################################################################################################################################################################################################### 100.0%
==> Fetching zstd
==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.5
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/zstd/blobs/sha256:e4eb8cc0473c699ec424bfecc67fcfd30631f7fe5eacf26c727bfed73dcf7c12
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:e4eb8cc0473c699ec424bfecc67fcfd30631f7fe5eacf26c727bfed73dcf7c12?se=2023-06-27T12%3A00%3A00Z&sig=b4EmOQ2f24dydA1UbVwE9R
##################################################################################################################################################################################################### 100.0%
==> Fetching llvm@15
==> Downloading https://ghcr.io/v2/homebrew/core/llvm/15/manifests/15.0.7
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/llvm/15/blobs/sha256:bf6135a0f1a083171f828cfb5a80f0a57177d01bc8bd27f6d18cee2b1d919303
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:bf6135a0f1a083171f828cfb5a80f0a57177d01bc8bd27f6d18cee2b1d919303?se=2023-06-27T12%3A00%3A00Z&sig=lxwFcvAl2DIJEt1gNjDyKc
##################################################################################################################################################################################################### 100.0%
==> Fetching openssl@3
==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/manifests/3.1.1_1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/blobs/sha256:a123a680d5fd22d094e2337101d3c8f8b8f78960c9ad4f07abbe3b025b8d36ff
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:a123a680d5fd22d094e2337101d3c8f8b8f78960c9ad4f07abbe3b025b8d36ff?se=2023-06-27T12%3A00%3A00Z&sig=fxxqGGdIzhG6tNjS8jrEsa
##################################################################################################################################################################################################### 100.0%
==> Fetching python@3.10
==> Downloading https://ghcr.io/v2/homebrew/core/python/3.10/manifests/3.10.12_1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/python/3.10/blobs/sha256:5529cfcd4eea11a32ce35b0e25e7954ba0a8013392d14727d48d75308362c22e
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:5529cfcd4eea11a32ce35b0e25e7954ba0a8013392d14727d48d75308362c22e?se=2023-06-27T12%3A00%3A00Z&sig=nj00FUvc9PGHmCTr6cy0xa
##################################################################################################################################################################################################### 100.0%
==> Fetching libpng
==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.40
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libpng/blobs/sha256:557a4044277365427a3f3e164de4b7376d8988bf2c065340827d333b96c540c3
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:557a4044277365427a3f3e164de4b7376d8988bf2c065340827d333b96c540c3?se=2023-06-27T12%3A00%3A00Z&sig=BrN2%2FYU3K3Mt9s%2FxNn
##################################################################################################################################################################################################### 100.0%
==> Fetching freetype
==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:872745894238fce7dba35a0add31b49b7c53150d9b7ee22a010104f0795895d2
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:872745894238fce7dba35a0add31b49b7c53150d9b7ee22a010104f0795895d2?se=2023-06-27T12%3A00%3A00Z&sig=kef5bsbfghjkoQ%2FerGVd
##################################################################################################################################################################################################### 100.0%
==> Fetching pcre2
==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/manifests/10.42
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/blobs/sha256:7f414ed9d561dc85aacd41c7d18a452d3f58a6fe73af02b8fb876483080ec4df
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:7f414ed9d561dc85aacd41c7d18a452d3f58a6fe73af02b8fb876483080ec4df?se=2023-06-27T12%3A00%3A00Z&sig=VvEUpiV3WHpjN9Id07SF4C
##################################################################################################################################################################################################### 100.0%
==> Fetching gettext
==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.21.1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/gettext/blobs/sha256:fd7e48065cf73e37dfdf4c5cb789a14b93cf58ac06060814a60c94b87d8f26e6
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:fd7e48065cf73e37dfdf4c5cb789a14b93cf58ac06060814a60c94b87d8f26e6?se=2023-06-27T12%3A00%3A00Z&sig=BURJDyeVFvysVisOM5avGX
##################################################################################################################################################################################################### 100.0%
==> Fetching glib
==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.76.3
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:7dc20de01d71f342361a7c989637671d163c8040e319fc93e3c7d34e92bff427
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:7dc20de01d71f342361a7c989637671d163c8040e319fc93e3c7d34e92bff427?se=2023-06-27T12%3A00%3A00Z&sig=Wuk4x7UDihnE3QGDO96%2F
##################################################################################################################################################################################################### 100.0%
==> Fetching jpeg-turbo
==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/2.1.5.1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/blobs/sha256:776ff10759a35f1ad39676e3a77ee25d88ae4d50fe31935fdba0fe197e455962
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:776ff10759a35f1ad39676e3a77ee25d88ae4d50fe31935fdba0fe197e455962?se=2023-06-27T12%3A00%3A00Z&sig=BieWL5%2FWhFAbqK2zvGQu
##################################################################################################################################################################################################### 100.0%
==> Fetching giflib
==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/giflib/blobs/sha256:7b542ce4281136276979dfbe45cea1a84060f624ee307917c24499398b210103
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:7b542ce4281136276979dfbe45cea1a84060f624ee307917c24499398b210103?se=2023-06-27T12%3A00%3A00Z&sig=%2FYM%2FC%2FXRGp8OjitK
##################################################################################################################################################################################################### 100.0%
==> Fetching libtiff
==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.5.1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/blobs/sha256:d802af35e9f79c5a0d230862219aa237761c310354ca181dc21ef80b4f35da40
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:d802af35e9f79c5a0d230862219aa237761c310354ca181dc21ef80b4f35da40?se=2023-06-27T12%3A00%3A00Z&sig=99exv2cIB37mJNbGDu7H6F
##################################################################################################################################################################################################### 100.0%
==> Fetching webp
==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.3.0_1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:7f0a23ef69c04d1994a5e1e5af7db6be289c3d45a88ce14de10b9d577da7637e
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:7f0a23ef69c04d1994a5e1e5af7db6be289c3d45a88ce14de10b9d577da7637e?se=2023-06-27T12%3A00%3A00Z&sig=fDiolZEFMIuGLxh1BN%2B8
##################################################################################################################################################################################################### 100.0%
==> Fetching qt@5
==> Downloading https://ghcr.io/v2/homebrew/core/qt/5/manifests/5.15.10
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/qt/5/blobs/sha256:d253e6509205cabb5c13ee228ec6fa0a405b46a4bdeca54001c2744dc4b3c710
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:d253e6509205cabb5c13ee228ec6fa0a405b46a4bdeca54001c2744dc4b3c710?se=2023-06-27T12%3A00%3A00Z&sig=dNsGOSLjyw%2FQVHqW9pl4
##################################################################################################################################################################################################### 100.0%
==> Fetching pyside@2
==> Downloading https://ghcr.io/v2/homebrew/core/pyside/2/manifests/5.15.10
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/pyside/2/blobs/sha256:43b8c564ba4bcae4efc92f5108c847c52fb91ca8bdee8d2c9090e8ac6c5ec8a7
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:43b8c564ba4bcae4efc92f5108c847c52fb91ca8bdee8d2c9090e8ac6c5ec8a7?se=2023-06-27T12%3A05%3A00Z&sig=bsqJb1y65%2FTKw87E9v33
##################################################################################################################################################################################################### 100.0%
==> Fetching python@3.11
==> Downloading https://ghcr.io/v2/homebrew/core/python/3.11/manifests/3.11.4_1
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/python/3.11/blobs/sha256:c97986e611c3c5e092be2ad70876fe99c7c7c23c8e7e63caaac6274512fbf657
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:c97986e611c3c5e092be2ad70876fe99c7c7c23c8e7e63caaac6274512fbf657?se=2023-06-27T12%3A05%3A00Z&sig=xTr6yAeZKovNwopde73Dko
##################################################################################################################################################################################################### 100.0%
==> Fetching cmake
==> Downloading https://ghcr.io/v2/homebrew/core/cmake/manifests/3.26.4
##################################################################################################################################################################################################### 100.0%
==> Downloading https://ghcr.io/v2/homebrew/core/cmake/blobs/sha256:7a48fae8706abac0d5c30e88c83bd8eed6fe44e0239ab30d1f20fd74433e5b30
==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sha256:7a48fae8706abac0d5c30e88c83bd8eed6fe44e0239ab30d1f20fd74433e5b30?se=2023-06-27T12%3A05%3A00Z&sig=1ZlUksYusz%2BiXAoKFOa4
##################################################################################################################################################################################################### 100.0%
==> Installing dependencies for pyside@2: lz4, zstd, llvm@15, openssl@3, python@3.10, libpng, freetype, pcre2, gettext, glib, jpeg-turbo, giflib, libtiff, webp and qt@5
==> Installing pyside@2 dependency: lz4
==> Pouring lz4--1.9.4.ventura.bottle.tar.gz
🍺  /usr/local/Cellar/lz4/1.9.4: 22 files, 684.9KB
==> Installing pyside@2 dependency: zstd
==> Pouring zstd--1.5.5.ventura.bottle.tar.gz
🍺  /usr/local/Cellar/zstd/1.5.5: 31 files, 2.5MB
==> Installing pyside@2 dependency: llvm@15
==> Pouring llvm@15--15.0.7.ventura.bottle.tar.gz
🍺  /usr/local/Cellar/llvm@15/15.0.7: 5,857 files, 1GB
==> Installing pyside@2 dependency: openssl@3
==> Pouring openssl@3--3.1.1_1.ventura.bottle.tar.gz
🍺  /usr/local/Cellar/openssl@3/3.1.1_1: 6,495 files, 29.9MB
==> Installing pyside@2 dependency: python@3.10
==> Pouring python@3.10--3.10.12_1.ventura.bottle.tar.gz

# %% [markdown]
# ## Main Solution: a new `requirements_osx.txt` file

# %%
requirements_osx.txt

# novel for pytorch DLC:
albumentations
timm
# old:
dlclibrary
ipython
filterpy
ruamel.yaml>=0.15.0
imageio-ffmpeg
imgaug==0.4.0
numba>=0.54.0
matplotlib<=3.5.2
networkx>=2.6
numpy>=1.18.5
pandas>=1.0.1,!=1.5.0
pyyaml
scikit-image>=0.17
scikit-learn>=1.0
scipy>=1.4,<1.11.0
statsmodels>=0.11
tensorflow>=2.0,<=2.10
tables==3.7.0
tensorpack==0.11
tf_slim==1.1.0
torch
torchvision
tqdm
Pillow>=7.1

# %%
pip install -r requirements_osx.txt
pip install ".[gui]"

# %%
pip install ".[gui]"                                                                                                           と言います!★ 
Processing /Users/rae/Desktop/DLCdev
  Preparing metadata (setup.py) ... done
Requirement already satisfied: dlclibrary in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (0.0.3)
Requirement already satisfied: filterpy>=1.4.4 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (1.4.5)
Requirement already satisfied: ruamel.yaml>=0.15.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (0.17.32)
Requirement already satisfied: imgaug>=0.4.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (0.4.0)
Requirement already satisfied: imageio-ffmpeg in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (0.4.8)
Requirement already satisfied: numba>=0.54 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (0.57.1)
Requirement already satisfied: matplotlib>=3.3 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (3.5.2)
Requirement already satisfied: networkx>=2.6 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (3.1)
Requirement already satisfied: numpy>=1.18.5 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (1.23.5)
Requirement already satisfied: pandas!=1.5.0,>=1.0.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (2.0.2)
Requirement already satisfied: scikit-image>=0.17 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (0.21.0)
Requirement already satisfied: scikit-learn>=1.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (1.2.2)
Collecting scipy<1.11.0,>=1.4 (from deeplabcut==2.3.1)
  Using cached scipy-1.10.1-cp39-cp39-macosx_10_9_x86_64.whl (35.2 MB)
Requirement already satisfied: statsmodels>=0.11 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (0.14.0)
Requirement already satisfied: tables>=3.7.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (3.7.0)
Requirement already satisfied: torch in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (2.0.1)
Requirement already satisfied: torchvision in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (0.15.2)
Requirement already satisfied: tensorpack>=0.11 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (0.11)
Requirement already satisfied: tf_slim>=1.1.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (1.1.0)
Requirement already satisfied: tqdm in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (4.65.0)
Requirement already satisfied: pyyaml in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (6.0)
Requirement already satisfied: Pillow>=7.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from deeplabcut==2.3.1) (9.5.0)
Collecting pyside6<6.3.2 (from deeplabcut==2.3.1)
  Using cached PySide6-6.3.1-cp36-abi3-macosx_10_9_universal2.whl (65 kB)
Collecting qdarkstyle==3.1 (from deeplabcut==2.3.1)
  Using cached QDarkStyle-3.1-py2.py3-none-any.whl (870 kB)
Collecting napari-deeplabcut>=0.0.9 (from deeplabcut==2.3.1)
  Using cached napari_deeplabcut-0.1.2-py3-none-any.whl (31 kB)
Collecting qtpy>=1.9 (from qdarkstyle==3.1->deeplabcut==2.3.1)
  Using cached QtPy-2.3.1-py3-none-any.whl (84 kB)
Requirement already satisfied: six in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from imgaug>=0.4.0->deeplabcut==2.3.1) (1.16.0)
Requirement already satisfied: opencv-python in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from imgaug>=0.4.0->deeplabcut==2.3.1) (4.7.0.72)
Requirement already satisfied: imageio in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from imgaug>=0.4.0->deeplabcut==2.3.1) (2.31.1)
Requirement already satisfied: Shapely in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from imgaug>=0.4.0->deeplabcut==2.3.1) (2.0.1)
Requirement already satisfied: cycler>=0.10 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut==2.3.1) (0.11.0)
Requirement already satisfied: fonttools>=4.22.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut==2.3.1) (4.40.0)
Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut==2.3.1) (1.4.4)
Requirement already satisfied: packaging>=20.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut==2.3.1) (23.1)
Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut==2.3.1) (3.1.0)
Requirement already satisfied: python-dateutil>=2.7 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from matplotlib>=3.3->deeplabcut==2.3.1) (2.8.2)
Collecting dask-image (from napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached dask_image-2023.3.0-py2.py3-none-any.whl (41 kB)
Collecting napari==0.4.17 (from napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached napari-0.4.17-py3-none-any.whl (2.6 MB)
Collecting natsort (from napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
Requirement already satisfied: opencv-python-headless in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (4.7.0.72)
Collecting appdirs>=1.4.4 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
Collecting app-model<0.3.0,>=0.0.8 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached app_model-0.1.4-py3-none-any.whl (57 kB)
Collecting cachey>=0.2.1 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached cachey-0.2.1-py3-none-any.whl (6.4 kB)
Requirement already satisfied: certifi>=2018.1.18 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (2023.5.7)
Collecting dask[array]!=2.28.0,>=2.15.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Downloading dask-2023.6.1-py3-none-any.whl (1.2 MB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 9.4 MB/s eta 0:00:00
Collecting jsonschema>=3.2.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
Collecting magicgui>=0.3.6 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached magicgui-0.7.2-py3-none-any.whl (120 kB)
Collecting napari-console>=0.0.6 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached napari_console-0.0.8-py3-none-any.whl (7.9 kB)
Collecting napari-plugin-engine>=0.1.9 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached napari_plugin_engine-0.2.0-py3-none-any.whl (33 kB)
Collecting napari-svg>=0.1.6 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached napari_svg-0.1.10-py3-none-any.whl (13 kB)
Collecting npe2>=0.5.2 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached npe2-0.7.0-py3-none-any.whl (92 kB)
Collecting numpydoc>=0.9.2 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached numpydoc-1.5.0-py3-none-any.whl (52 kB)
Collecting pint>=0.17 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Downloading Pint-0.22-py3-none-any.whl (294 kB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.0/294.0 kB 5.9 MB/s eta 0:00:00
Requirement already satisfied: psutil>=5.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (5.9.5)
Collecting psygnal>=0.3.4 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Downloading psygnal-0.9.1-cp39-cp39-macosx_10_16_x86_64.whl (399 kB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.5/399.5 kB 4.8 MB/s eta 0:00:00
Collecting pydantic>=1.9.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached pydantic-1.10.9-cp39-cp39-macosx_10_9_x86_64.whl (2.9 MB)
Requirement already satisfied: pygments>=2.4.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (2.15.1)
Collecting PyOpenGL>=3.1.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached PyOpenGL-3.1.7-py3-none-any.whl (2.4 MB)
Collecting sphinx<5 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached Sphinx-4.5.0-py3-none-any.whl (3.1 MB)
Collecting superqt>=0.3.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached superqt-0.4.1-py3-none-any.whl (63 kB)
Requirement already satisfied: tifffile>=2020.2.16 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (2023.4.12)
Collecting toolz>=0.10.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
Requirement already satisfied: typing-extensions in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (4.6.3)
Collecting vispy<0.12,>=0.11.0 (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Downloading vispy-0.11.0-cp39-cp39-macosx_10_9_x86_64.whl (1.4 MB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 13.2 MB/s eta 0:00:00
Requirement already satisfied: wrapt>=1.11.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (1.14.1)
Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from numba>=0.54->deeplabcut==2.3.1) (0.40.1)
Requirement already satisfied: pytz>=2020.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from pandas!=1.5.0,>=1.0.1->deeplabcut==2.3.1) (2023.3)
Requirement already satisfied: tzdata>=2022.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from pandas!=1.5.0,>=1.0.1->deeplabcut==2.3.1) (2023.3)
Collecting shiboken6==6.3.1 (from pyside6<6.3.2->deeplabcut==2.3.1)
  Using cached shiboken6-6.3.1-cp36-abi3-macosx_10_9_universal2.whl (383 kB)
Collecting PySide6-Essentials==6.3.1 (from pyside6<6.3.2->deeplabcut==2.3.1)
  Using cached PySide6_Essentials-6.3.1-cp36-abi3-macosx_10_9_universal2.whl (130.2 MB)
Collecting PySide6-Addons==6.3.1 (from pyside6<6.3.2->deeplabcut==2.3.1)
  Using cached PySide6_Addons-6.3.1-cp36-abi3-macosx_10_9_universal2.whl (212.9 MB)
Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from ruamel.yaml>=0.15.0->deeplabcut==2.3.1) (0.2.7)
Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from scikit-image>=0.17->deeplabcut==2.3.1) (1.4.1)
Requirement already satisfied: lazy_loader>=0.2 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from scikit-image>=0.17->deeplabcut==2.3.1) (0.2)
Requirement already satisfied: joblib>=1.1.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from scikit-learn>=1.0->deeplabcut==2.3.1) (1.2.0)
Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from scikit-learn>=1.0->deeplabcut==2.3.1) (3.1.0)
Requirement already satisfied: patsy>=0.5.2 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from statsmodels>=0.11->deeplabcut==2.3.1) (0.5.3)
Requirement already satisfied: numexpr>=2.6.2 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from tables>=3.7.0->deeplabcut==2.3.1) (2.8.4)
Requirement already satisfied: termcolor>=1.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from tensorpack>=0.11->deeplabcut==2.3.1) (2.3.0)
Requirement already satisfied: tabulate>=0.7.7 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from tensorpack>=0.11->deeplabcut==2.3.1) (0.9.0)
Requirement already satisfied: msgpack>=0.5.2 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from tensorpack>=0.11->deeplabcut==2.3.1) (1.0.5)
Requirement already satisfied: msgpack-numpy>=0.4.4.2 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from tensorpack>=0.11->deeplabcut==2.3.1) (0.4.8)
Requirement already satisfied: pyzmq>=16 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from tensorpack>=0.11->deeplabcut==2.3.1) (25.1.0)
Requirement already satisfied: absl-py>=0.2.2 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from tf_slim>=1.1.0->deeplabcut==2.3.1) (1.4.0)
Requirement already satisfied: huggingface-hub in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from dlclibrary->deeplabcut==2.3.1) (0.15.1)
Requirement already satisfied: filelock in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from torch->deeplabcut==2.3.1) (3.12.2)
Requirement already satisfied: sympy in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from torch->deeplabcut==2.3.1) (1.12)
Requirement already satisfied: jinja2 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from torch->deeplabcut==2.3.1) (3.1.2)
Requirement already satisfied: requests in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from torchvision->deeplabcut==2.3.1) (2.31.0)
Collecting pims>=0.4.1 (from dask-image->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached PIMS-0.6.1.tar.gz (86 kB)
  Preparing metadata (setup.py) ... done
Requirement already satisfied: fsspec in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from huggingface-hub->dlclibrary->deeplabcut==2.3.1) (2023.6.0)
Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from jinja2->torch->deeplabcut==2.3.1) (2.1.3)
Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from requests->torchvision->deeplabcut==2.3.1) (3.1.0)
Requirement already satisfied: idna<4,>=2.5 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from requests->torchvision->deeplabcut==2.3.1) (3.4)
Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from requests->torchvision->deeplabcut==2.3.1) (1.26.16)
Requirement already satisfied: mpmath>=0.19 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from sympy->torch->deeplabcut==2.3.1) (1.3.0)
Collecting in-n-out>=0.1.5 (from app-model<0.3.0,>=0.0.8->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached in_n_out-0.1.7-py3-none-any.whl (19 kB)
Collecting heapdict (from cachey>=0.2.1->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
Collecting click>=8.0 (from dask[array]!=2.28.0,>=2.15.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached click-8.1.3-py3-none-any.whl (96 kB)
Collecting cloudpickle>=1.5.0 (from dask[array]!=2.28.0,>=2.15.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
Collecting partd>=1.2.0 (from dask[array]!=2.28.0,>=2.15.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached partd-1.4.0-py3-none-any.whl (18 kB)
Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from dask[array]!=2.28.0,>=2.15.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (6.7.0)
Collecting attrs>=17.4.0 (from jsonschema>=3.2.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema>=3.2.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached pyrsistent-0.19.3-cp39-cp39-macosx_10_9_universal2.whl (82 kB)
Collecting docstring-parser>=0.7 (from magicgui>=0.3.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached docstring_parser-0.15-py3-none-any.whl (36 kB)
Collecting ipykernel>=5.2.0 (from napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached ipykernel-6.23.3-py3-none-any.whl (152 kB)
Requirement already satisfied: IPython>=7.7.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (8.14.0)
Collecting qtconsole!=4.7.6,!=5.4.2,>=4.5.1 (from napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached qtconsole-5.4.3-py3-none-any.whl (121 kB)
Collecting build (from npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached build-0.10.0-py3-none-any.whl (17 kB)
Collecting pytomlpp (from npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Downloading pytomlpp-1.0.13-cp39-cp39-macosx_10_9_x86_64.whl (188 kB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.2/188.2 kB 5.0 MB/s eta 0:00:00
Collecting rich (from npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached rich-13.4.2-py3-none-any.whl (239 kB)
Collecting typer (from npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached typer-0.9.0-py3-none-any.whl (45 kB)
Collecting slicerator>=0.9.8 (from pims>=0.4.1->dask-image->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached slicerator-1.1.0-py3-none-any.whl (10 kB)
Collecting mypy-extensions (from psygnal>=0.3.4->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
Collecting sphinxcontrib-applehelp (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached sphinxcontrib_applehelp-1.0.4-py3-none-any.whl (120 kB)
Collecting sphinxcontrib-devhelp (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
Collecting sphinxcontrib-jsmath (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
Collecting sphinxcontrib-htmlhelp>=2.0.0 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached sphinxcontrib_htmlhelp-2.0.1-py3-none-any.whl (99 kB)
Collecting sphinxcontrib-serializinghtml>=1.1.5 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
Collecting sphinxcontrib-qthelp (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
Collecting docutils<0.18,>=0.14 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached docutils-0.17.1-py2.py3-none-any.whl (575 kB)
Collecting snowballstemmer>=1.1 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
Collecting babel>=1.3 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached Babel-2.12.1-py3-none-any.whl (10.1 MB)
Collecting alabaster<0.8,>=0.7 (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached alabaster-0.7.13-py3-none-any.whl (13 kB)
Collecting imagesize (from sphinx<5->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
Collecting freetype-py (from vispy<0.12,>=0.11.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached freetype_py-2.4.0-py3-none-macosx_10_9_universal2.whl (1.8 MB)
Collecting hsluv (from vispy<0.12,>=0.11.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached hsluv-5.0.3-py2.py3-none-any.whl (5.1 kB)
Requirement already satisfied: zipp>=0.5 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask[array]!=2.28.0,>=2.15.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (3.15.0)
Requirement already satisfied: appnope in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (0.1.3)
Collecting comm>=0.1.1 (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached comm-0.1.3-py3-none-any.whl (6.6 kB)
Collecting debugpy>=1.6.5 (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Downloading debugpy-1.6.7-py2.py3-none-any.whl (4.9 MB)
     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 11.9 MB/s eta 0:00:00
Collecting jupyter-client>=6.1.12 (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached jupyter_client-8.3.0-py3-none-any.whl (103 kB)
Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached jupyter_core-5.3.1-py3-none-any.whl (93 kB)
Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (0.1.6)
Collecting nest-asyncio (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
Collecting tornado>=6.1 (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached tornado-6.3.2-cp38-abi3-macosx_10_9_x86_64.whl (422 kB)
Requirement already satisfied: traitlets>=5.4.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (5.9.0)
Requirement already satisfied: backcall in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (0.2.0)
Requirement already satisfied: decorator in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (5.1.1)
Requirement already satisfied: jedi>=0.16 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (0.18.2)
Requirement already satisfied: pickleshare in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (0.7.5)
Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (3.0.38)
Requirement already satisfied: stack-data in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (0.6.2)
Requirement already satisfied: pexpect>4.3 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (4.8.0)
Collecting locket (from partd>=1.2.0->dask[array]!=2.28.0,>=2.15.0->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
Collecting ipython-genutils (from qtconsole!=4.7.6,!=5.4.2,>=4.5.1->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
Collecting pyproject_hooks (from build->npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
Collecting tomli>=1.1.0 (from build->npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
Collecting markdown-it-py>=2.2.0 (from rich->npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from jedi>=0.16->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (0.8.3)
Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.2.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached platformdirs-3.8.0-py3-none-any.whl (16 kB)
Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->npe2>=0.5.2->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1)
  Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
Requirement already satisfied: ptyprocess>=0.5 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from pexpect>4.3->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (0.7.0)
Requirement already satisfied: wcwidth in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (0.2.6)
Requirement already satisfied: executing>=1.2.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (1.2.0)
Requirement already satisfied: asttokens>=2.1.0 in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (2.2.1)
Requirement already satisfied: pure-eval in /usr/local/anaconda3/envs/dlc/lib/python3.9/site-packages (from stack-data->IPython>=7.7.0->napari-console>=0.0.6->napari==0.4.17->napari-deeplabcut>=0.0.9->deeplabcut==2.3.1) (0.2.2)
Building wheels for collected packages: deeplabcut, pims
  Building wheel for deeplabcut (setup.py) ... done
  Created wheel for deeplabcut: filename=deeplabcut-2.3.1-py3-none-any.whl size=1431719 sha256=22cdd23196d82473ee2a16d1b53e6a4c367fb82a89f230df06e0ee6ce897f6f1
  Stored in directory: /private/var/folders/ct/yqddf6yn3fb26n4v2bp3mxxw0000gq/T/pip-ephem-wheel-cache-oo0q8s3s/wheels/42/26/9f/c5d08444c2ec50c15b21dc8f9ea2ffb1aa91840cd6e62b8153
  Building wheel for pims (setup.py) ... done
  Created wheel for pims: filename=PIMS-0.6.1-py3-none-any.whl size=82621 sha256=88da71b2ebc8fa6c277530e611fc0afa28e0246f2eed5d4b8e20c1adc681dcfc
  Stored in directory: /Users/rae/Library/Caches/pip/wheels/c8/51/78/e8155864f53ff0c9e01fe656f64b55712ba60fb2a451757505
Successfully built deeplabcut pims
Installing collected packages: snowballstemmer, slicerator, pytomlpp, PyOpenGL, ipython-genutils, heapdict, appdirs, tornado, toolz, tomli, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, shiboken6, scipy, qtpy, pyrsistent, pydantic, platformdirs, pint, nest-asyncio, natsort, napari-plugin-engine, mypy-extensions, mdurl, locket, in-n-out, imagesize, hsluv, freetype-py, docutils, docstring-parser, debugpy, comm, cloudpickle, click, cachey, babel, attrs, alabaster, vispy, typer, superqt, sphinx, qdarkstyle, PySide6-Essentials, pyproject_hooks, psygnal, pims, partd, markdown-it-py, jupyter-core, jsonschema, rich, PySide6-Addons, numpydoc, napari-svg, magicgui, jupyter-client, dask, build, app-model, pyside6, npe2, ipykernel, deeplabcut, qtconsole, dask-image, napari-console, napari, napari-deeplabcut
  Attempting uninstall: scipy
    Found existing installation: scipy 1.11.0
    Uninstalling scipy-1.11.0:
      Successfully uninstalled scipy-1.11.0
Successfully installed PyOpenGL-3.1.7 PySide6-Addons-6.3.1 PySide6-Essentials-6.3.1 alabaster-0.7.13 app-model-0.1.4 appdirs-1.4.4 attrs-23.1.0 babel-2.12.1 build-0.10.0 cachey-0.2.1 click-8.1.3 cloudpickle-2.2.1 comm-0.1.3 dask-2023.6.1 dask-image-2023.3.0 debugpy-1.6.7 deeplabcut-2.3.1 docstring-parser-0.15 docutils-0.17.1 freetype-py-2.4.0 heapdict-1.0.1 hsluv-5.0.3 imagesize-1.4.1 in-n-out-0.1.7 ipykernel-6.23.3 ipython-genutils-0.2.0 jsonschema-4.17.3 jupyter-client-8.3.0 jupyter-core-5.3.1 locket-1.0.0 magicgui-0.7.2 markdown-it-py-3.0.0 mdurl-0.1.2 mypy-extensions-1.0.0 napari-0.4.17 napari-console-0.0.8 napari-deeplabcut-0.1.2 napari-plugin-engine-0.2.0 napari-svg-0.1.10 natsort-8.4.0 nest-asyncio-1.5.6 npe2-0.7.0 numpydoc-1.5.0 partd-1.4.0 pims-0.6.1 pint-0.22 platformdirs-3.8.0 psygnal-0.9.1 pydantic-1.10.9 pyproject_hooks-1.0.0 pyrsistent-0.19.3 pyside6-6.3.1 pytomlpp-1.0.13 qdarkstyle-3.1 qtconsole-5.4.3 qtpy-2.3.1 rich-13.4.2 scipy-1.10.1 shiboken6-6.3.1 slicerator-1.1.0 snowballstemmer-2.2.0 sphinx-4.5.0 sphinxcontrib-applehelp-1.0.4 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5 superqt-0.4.1 tomli-2.0.1 toolz-0.12.0 tornado-6.3.2 typer-0.9.0 vispy-0.11.0

# %% [markdown]
# ![working.png](attachment:working.png)
